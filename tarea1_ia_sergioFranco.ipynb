# %%
## taller 01_ Sergio Steven Franco Arboleda

# %%
import numpy  #as np# si no lo tiene instalado por favor correr en su consola         $pip install numpy
import scipy #as sp# si no lo tiene instalado por favor correr en su consola         $pip install scipy
import matplotlib #si no lo tiene instalado por favor correr  en su consola   $pip install matplotlib
import matplotlib.pyplot as plt

# %%
##Primer punto Distribuciones discretas.
#1. Cree un arreglo de N muestras con N a su selección, pero mayor a 1000, de números distribuidos con las correspondientes distribuciones, para cada arreglo de números:
#2. Grafique los números aleatorios,
#3. Ordene de menor a mayor y grafique,
#4. Encuentre los valores teoricos de media y varianza, y comparelos con los estimados.

# %%
#Para todas las simulaciones:
N=100000
m=3000
m1=100
numpy.random.seed(seed=2**32 - 1)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# bernoulli con cierto p entre 0 y 1
p=0.3
from scipy.stats import bernoulli
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
r = bernoulli.rvs(p, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la bernoulli con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la bernoulli con p= 0.3 son u= 0.3 var= 0.21
# Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p= 0.3 son u_est= 0.29788 var_est= 0.20914750559999998

# %% [markdown]
# Desarrollo

# %%
# binomial con cierto p entre 0 y 1 y cierto n

from scipy.stats import binom
n1,p1 = 10, 0.5
mean1, var1, skew1, kurt1 = binom.stats(n1, p1, moments='mvsk')
r1 = binom.rvs(n1, p1, size=N)
plt.plot(r1)
plt.title(str(N)+" puntos distribuidos binomialmente con p="+str(p1))
plt.show()
print("Los valores teoricos de la media y varianza para la binomial con p=",p1,"son u=" ,mean1,"var=",var1)

##-----
r1.sort()
plt.plot(r1)
plt.title(str(N)+" puntos distribuidos de forma Binomial ordenados con p="+str(p1)+ " y n= "+ str(n1))
plt.show()

##-----
plt.hist(r1, bins=m1)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomial con p="+str(p1) + " y n= "+ str(n1))
plt.show()
# Out:
# Los valores teoricos de la media y varianza para la binomial con p= 0.5 son u= 5.0 var= 2.5

# %%
#comparación valores estimados y teóricos
med_estimada1=r1.mean()
var_estimada1=r1.var()
print( "Valores teóricos vs estimados de distribución binomial con p=", p1, "y n=", n1)
print("Varianza teórica=", var1, "media teórica=", mean1)
print("Varianza estimada=", var_estimada1, "media estimada=", med_estimada1)
# Out:
# Valores teóricos vs estimados de distribución binomial con p= 0.5 y n= 10
# Varianza teórica= 2.5 media teórica= 5.0
# Varianza estimada= 2.4975198063999993 media estimada= 4.99956

# %%
# Geométrica con cierto p entre 0 y 1

from scipy.stats import geom
p1 = 0.3
mean1, var1, skew1, kurt1 = geom.stats(p1, moments='mvsk')
r1 = geom.rvs(p1, size=N)
plt.plot(r1)
plt.title(str(N)+" puntos distribuidos geomentric con p="+str(p1))
plt.show()
print("Los valores teoricos de la media y varianza para la geometrica con p=",p1,"son u=" ,mean1,"var=",var1)

##---
r1.sort()
plt.plot(r1)
plt.title(str(N)+" puntos distribuidos Geometricamente ordenados con p="+str(p1))
plt.show()

##---
plt.hist(r1, bins=m1)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Geometricamente con p="+str(p1))
plt.show()
# Out:
# Los valores teoricos de la media y varianza para la geometrica con p= 0.3 son u= 3.3333333333333335 var= 7.777777777777779

# %%
#comparación valores estimados y teóricos
med_estimada1=r1.mean()
var_estimada1=r1.var()
print( "Valores teóricos vs estimados de distribución binomial con p=", p1)
print("Varianza teórica=", var1, "media teórica=", mean1)
print("Varianza estimada=", var_estimada1, "media estimada=", med_estimada1)
# Out:
# Valores teóricos vs estimados de distribución binomial con p= 0.3
# Varianza teórica= 7.777777777777779 media teórica= 3.3333333333333335
# Varianza estimada= 7.7730679600000006 media estimada= 3.3302

# %%
# Poisson con cierto Lamnda L
L = 5
from scipy.stats import poisson

mean1, var1, skew1, kurt1 = poisson.stats(L, moments='mvsk')
r1 = poisson.rvs(L, size=N)

plt.plot(r1)
plt.title(str(N)+" puntos distribuidos poisson con L="+str(L))
plt.show()
print("Los valores teoricos de la media y varianza para Poisson con L=",L,"son u=" ,mean1,"var=",var1)

##------
r1.sort()
plt.plot(r1)
plt.title(str(N)+" puntos distribuidos Poisson ordenados con L="+str(L))
plt.show()

##-------
plt.hist(r1, bins=m1)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Poisson con L="+str(L))
plt.show()
# Out:
# Los valores teoricos de la media y varianza para Poisson con L= 5 son u= 5.0 var= 5.0

# %%
#comparación valores estimados y teóricos
med_estimada1=r1.mean()
var_estimada1=r1.var()
print( "Valores teóricos vs estimados de distribución Poisson con L=", L)
print("Varianza teórica=", var1, "media teórica=", mean1)
print("Varianza estimada=", var_estimada1, "media estimada=", med_estimada1)
# Out:
# Valores teóricos vs estimados de distribución Poisson con L= 5
# Varianza teórica= 5.0 media teórica= 5.0
# Varianza estimada= 4.9719699375 media estimada= 5.00025

# %%
#Binomial negativa con parametro p después de r fallos

from scipy.stats import nbinom
n1, p1= 5, 0.5
mean1, var1, skew1, kurt1 = nbinom.stats(n1, p1, moments='mvsk')
r1 = nbinom.rvs(n1, p1, size=N)
plt.plot(r1)
plt.title(str(N)+" puntos distribuidos de forma binomial negativa con p: "+str(p1)+"y n: "+str(n1))
plt.show()
print("Los valores teoricos de la media y varianza para nbinomial con p: 0.5 y n: 5 ,son u=" ,mean1,"var=",var1)

##----
r1.sort()
plt.plot(r1)
plt.title(str(N)+" puntos distribuidos  ordenados con p="+str(p1)+ " y n= "+ str(n1))
plt.show()

##----
plt.hist(r1, bins=m1)
plt.title("Histograma de los "+str(N)+" puntos distribuidos nbinomial con p="+str(p1) + " y n= "+ str(n1))
plt.show()
# Out:
# Los valores teoricos de la media y varianza para nbinomial con p: 0.5 y n: 5 ,son u= 5.0 var= 10.0

# %%
#comparación valores estimados y teóricos
med_estimada1=r1.mean()
var_estimada1=r1.var()
print( "Valores teóricos vs estimados de distribución binomial con p=", p1, "y n=", n1)
print("Varianza teórica=", var1, "media teórica=", mean1)
print("Varianza estimada=", var_estimada1, "media estimada=", med_estimada1)
# Out:
# Valores teóricos vs estimados de distribución binomial con p= 0.5 y n= 5
# Varianza teórica= 10.0 media teórica= 5.0
# Varianza estimada= 9.9615473719 media estimada= 4.99091

# %% [markdown]
# Segundo punto Distribuciones contínuas.

# %%
#Para todas las simulaciones:
N=10000
m=300
numpy.random.seed(seed=1314926535)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# Normal de media 5 y desviación estandar 0.5
u=5
std=0.5
mean, var, skew, kurt = scipy.stats.norm.stats(moments='mvsk',loc=u,scale=std)
r = scipy.stats.norm.rvs (loc=u,scale=std, size=N2)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales con media="+str(u)+" y std="+str(std))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales ordenados con p="+str(p))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales con u="+str(u)+ " y std= "+str(std))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 5.0 var= 0.25
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 4.9904830572215415 var_est= 0.24343895999254364

# %%
# Uniforme entre 0 y 255

from scipy.stats import uniform 
mean1, var1, skew1, kurt1 = uniform.stats(moments='mvsk')
r1=uniform.rvs(loc=0, scale=255, size=N)

##---
plt.plot(r1)
plt.title(str(N)+" puntos distribuidos uniformemente entre 0 y 255")
plt.show()

##---
r1.sort()
plt.plot(r1)
plt.title(str(N)+" puntos distribuidos uniformes ordenados")
plt.show()

##---
plt.hist(r1, bins=m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos uniformemente  entre 0 y 255")
plt.show()
# Out:
# Valores teóricos vs estimados de distribución iniforme
# Varianza teórica= 0.08333333333333333 media teórica= 0.5
# Varianza estimada= 5411.191670493089 media estimada= 126.7767595080859

# %%
#comparación valores estimados y teóricos
med_estimada1=r1.mean()
var_estimada1=r1.var()
print( "Valores teóricos vs estimados de distribución iniforme")
print("Varianza teórica=", var1, "media teórica=", mean1)
print("Varianza estimada=", var_estimada1, "media estimada=", med_estimada1)

# %%
# Exponencial con Lamnda L
L=0.3
from scipy.stats import expon 
mean1, var1, skew1, kurt1 = expon.stats(moments='mvsk')
r1=expon.rvs(size=N)

plt.plot(r1)
plt.title(str(N)+" puntos distribuidos exponecialmete con Lamnda= "+str(L))
plt.show()

r1.sort()
plt.plot(r1)
plt.title(str(N)+" puntos distribuidos exponencialmente ordenados")
plt.show()


plt.hist(r1, bins=m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos exponencialmete")
plt.show()

# %%
#comparación valores estimados y teóricos
med_estimada1=r1.mean()
var_estimada1=r1.var()
print( "Valores teóricos vs estimados de distribución exponencial")
print("Varianza teórica=", var1, "media teórica=", mean1)
print("Varianza estimada=", var_estimada1, "media estimada=", med_estimada1)
# Out:
# Valores teóricos vs estimados de distribución exponencial
# Varianza teórica= 1.0 media teórica= 1.0
# Varianza estimada= 0.9990583881864626 media estimada= 0.9998320300693393

# %%
#Chi cuadrada con K grados de libertad
K=3.0
from scipy.stats import chi2 
mean1, var1, skew1, kurt1= chi2.stats(K, moments='mvsk')
r1=chi2.rvs(K, size=N)

plt.plot(r1)
plt.title(str(N)+" puntos distribuidos Chi cuadrada con K= "+str(K))
plt.show()

r1.sort()
plt.plot(r1)
plt.title(str(N)+" puntos distribuidos Chi cuadrada ordenados")
plt.show()


plt.hist(r1, bins=m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Chi cuadrada")
plt.show()

# %%
#comparación valores estimados y teóricos
med_estimada1=r1.mean()
var_estimada1=r1.var()
print( "Valores teóricos vs estimados de distribución Chi cuadrada")
print("Varianza teórica=", var1, "media teórica=", mean1)
print("Varianza estimada=", var_estimada1, "media estimada=", med_estimada1)
# Out:
# Valores teóricos vs estimados de distribución Chi cuadrada
# Varianza teórica= 6.0 media teórica= 3.0
# Varianza estimada= 5.906732212563823 media estimada= 2.985784179033093

# %%
#Gamma con parametros k y theta t
k,t=2.54,0.43
theta=1/t
from scipy.stats import gamma 
mean1, var1, skew1, kurt1= gamma.stats(k, moments='mvsk')
r1=gamma.rvs(k, scale=theta, size=N)

plt.plot(r1)
plt.title(str(N)+" puntos distribuidos Gamma con k= "+str(k))
plt.show()

r1.sort()
plt.plot(r1)
plt.title(str(N)+" puntos distribuidos Gamma ordenados")
plt.show()


plt.hist(r1, bins=m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Gamma")
plt.show()

# %%
#comparación valores estimados y teóricos
med_estimada1=r1.mean()
var_estimada1=r1.var()
print( "Valores teóricos vs estimados de distribución Gamma")
print("Varianza teórica=", var1, "media teórica=", mean1)
print("Varianza estimada=", var_estimada1, "media estimada=", med_estimada1)
# Out:
# Valores teóricos vs estimados de distribución Gamma
# Varianza teórica= 0.08333333333333333 media teórica= 0.5
# Varianza estimada= 5411.191670493089 media estimada= 126.7767595080859
